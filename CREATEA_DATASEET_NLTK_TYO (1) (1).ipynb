# %%
import pandas as pd

# %%
data = pd.read_excel('/content/drive/MyDrive/TYO_NLTK/DATASHEET BERITA.xlsx')

# %%
data = data[['HEADLINE','CATEGORY']]

# %%
data.head(10)
# Out:
#                                             HEADLINE   CATEGORY
# 0  Hasil Liga Inggris 2022-2023 Semalam: Everton ...  OLAH RAGA
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...  OLAH RAGA
# 2  NBA Pramusim 2022-2023: Giannis Antetokounmpo ...  OLAH RAGA
# 3  Jelang FIBA World Cup 2023: Dikonfirmasi Dirut...  OLAH RAGA
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022: Mi...  OLAH RAGA
# 5  Usai Bekuk Real Sociedad, Manchester United La...  OLAH RAGA
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...  OLAH RAGA
# 7  Hasil NBA 2022-2023 Hari Ini: Milwaukee Bucks ...  OLAH RAGA
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022  OLAH RAGA
# 9  Hasil Semifinal Hylo Open 2022: Hajar Unggulan...  OLAH RAGA

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# Hilangakn tanda baca

# %%
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

data['HEADLINE_CLEAN'] = data['HEADLINE'].apply(lambda x: remove_punct(x))

data.head(10)
# Out:
#                                             HEADLINE   CATEGORY  \
# 0  Hasil Liga Inggris 2022-2023 Semalam: Everton ...  OLAH RAGA
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...  OLAH RAGA
# 2  NBA Pramusim 2022-2023: Giannis Antetokounmpo ...  OLAH RAGA
# 3  Jelang FIBA World Cup 2023: Dikonfirmasi Dirut...  OLAH RAGA
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022: Mi...  OLAH RAGA
# 5  Usai Bekuk Real Sociedad, Manchester United La...  OLAH RAGA
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...  OLAH RAGA
# 7  Hasil NBA 2022-2023 Hari Ini: Milwaukee Bucks ...  OLAH RAGA
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022  OLAH RAGA
# 9  Hasil Semifinal Hylo Open 2022: Hajar Unggulan...  OLAH RAGA
#
#                                       HEADLINE_CLEAN
# 0  Hasil Liga Inggris 20222023 Semalam Everton vs...
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...
# 2  NBA Pramusim 20222023 Giannis Antetokounmpo In...
# 3  Jelang FIBA World Cup 2023 Dikonfirmasi Dirut ...
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022 Mig...
# 5  Usai Bekuk Real Sociedad Manchester United Lan...
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...
# 7  Hasil NBA 20222023 Hari Ini Milwaukee Bucks Ma...
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022
# 9  Hasil Semifinal Hylo Open 2022 Hajar Unggulan ...

# %%
import re

def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

data['HEADLINE_TOKENIZE'] = data['HEADLINE_CLEAN'].apply(lambda x: tokenize(x.lower()))

data.head(10)
# Out:
#                                             HEADLINE   CATEGORY  \
# 0  Hasil Liga Inggris 2022-2023 Semalam: Everton ...  OLAH RAGA
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...  OLAH RAGA
# 2  NBA Pramusim 2022-2023: Giannis Antetokounmpo ...  OLAH RAGA
# 3  Jelang FIBA World Cup 2023: Dikonfirmasi Dirut...  OLAH RAGA
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022: Mi...  OLAH RAGA
# 5  Usai Bekuk Real Sociedad, Manchester United La...  OLAH RAGA
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...  OLAH RAGA
# 7  Hasil NBA 2022-2023 Hari Ini: Milwaukee Bucks ...  OLAH RAGA
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022  OLAH RAGA
# 9  Hasil Semifinal Hylo Open 2022: Hajar Unggulan...  OLAH RAGA
#
#                                       HEADLINE_CLEAN  \
# 0  Hasil Liga Inggris 20222023 Semalam Everton vs...
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...
# 2  NBA Pramusim 20222023 Giannis Antetokounmpo In...
# 3  Jelang FIBA World Cup 2023 Dikonfirmasi Dirut ...
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022 Mig...
# 5  Usai Bekuk Real Sociedad Manchester United Lan...
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...
# 7  Hasil NBA 20222023 Hari Ini Milwaukee Bucks Ma...
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022
# 9  Hasil Semifinal Hylo Open 2022 Hajar Unggulan ...
#
#                                    HEADLINE_TOKENIZE
# 0  [hasil, liga, inggris, 20222023, semalam, ever...
# 1  [diogo, dalot, dapat, pujian, usai, tampil, ci...
# 2  [nba, pramusim, 20222023, giannis, antetokounm...
# 3  [jelang, fiba, world, cup, 2023, dikonfirmasi,...
# 4  [hasil, latihan, bebas, 4, motogp, valencia, 2...
# 5  [usai, bekuk, real, sociedad, manchester, unit...
# 6  [perbasi, kirim, 20, pemain, muda, jalani, tc,...
# 7  [hasil, nba, 20222023, hari, ini, milwaukee, b...
# 8  [ben, chilwell, dipastikan, absen, di, piala, ...
# 9  [hasil, semifinal, hylo, open, 2022, hajar, un...

# %% [markdown]
# Hilangkan STOPWORD dalam bahasa Indonesia

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopword = nltk.corpus.stopwords.words('indonesian')

# %%
stopword[:5]
stopword = [f' {x} ' for x in stopword]
stopword[:5]
# Out:
# [' ada ', ' adalah ', ' adanya ', ' adapun ', ' agak ']

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text

data['HEADLINE_NON_STP'] = data['HEADLINE_TOKENIZE'].apply(lambda x: remove_stopwords(x))

data.head(10)
# Out:
#                                             HEADLINE   CATEGORY  \
# 0  Hasil Liga Inggris 2022-2023 Semalam: Everton ...  OLAH RAGA
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...  OLAH RAGA
# 2  NBA Pramusim 2022-2023: Giannis Antetokounmpo ...  OLAH RAGA
# 3  Jelang FIBA World Cup 2023: Dikonfirmasi Dirut...  OLAH RAGA
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022: Mi...  OLAH RAGA
# 5  Usai Bekuk Real Sociedad, Manchester United La...  OLAH RAGA
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...  OLAH RAGA
# 7  Hasil NBA 2022-2023 Hari Ini: Milwaukee Bucks ...  OLAH RAGA
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022  OLAH RAGA
# 9  Hasil Semifinal Hylo Open 2022: Hajar Unggulan...  OLAH RAGA
#
#                                       HEADLINE_CLEAN  \
# 0  Hasil Liga Inggris 20222023 Semalam Everton vs...
# 1  Diogo Dalot Dapat Pujian Usai Tampil Ciamik Ke...
# 2  NBA Pramusim 20222023 Giannis Antetokounmpo In...
# 3  Jelang FIBA World Cup 2023 Dikonfirmasi Dirut ...
# 4  Hasil Latihan Bebas 4 MotoGP Valencia 2022 Mig...
# 5  Usai Bekuk Real Sociedad Manchester United Lan...
# 6  Perbasi Kirim 20 Pemain Muda Jalani TC ke Amer...
# 7  Hasil NBA 20222023 Hari Ini Milwaukee Bucks Ma...
# 8  Ben Chilwell Dipastikan Absen di Piala Dunia 2022
# 9  Hasil Semifinal Hylo Open 2022 Hajar Unggulan ...
#
#                                    HEADLINE_TOKENIZE  \
# 0  [hasil, liga, inggris, 20222023, semalam, ever...
# 1  [diogo, dalot, dapat, pujian, usai, tampil, ci...
# 2  [nba, pramusim, 20222023, giannis, antetokounm...
# 3  [jelang, fiba, world, cup, 2023, dikonfirmasi,...
# 4  [hasil, latihan, bebas, 4, motogp, valencia, 2...
# 5  [usai, bekuk, real, sociedad, manchester, unit...
# 6  [perbasi, kirim, 20, pemain, muda, jalani, tc,...
# 7  [hasil, nba, 20222023, hari, ini, milwaukee, b...
# 8  [ben, chilwell, dipastikan, absen, di, piala, ...
# 9  [hasil, semifinal, hylo, open, 2022, hajar, un...
#
#                                     HEADLINE_NON_STP
# 0  [hasil, liga, inggris, 20222023, semalam, ever...
# 1  [diogo, dalot, dapat, pujian, usai, tampil, ci...
# 2  [nba, pramusim, 20222023, giannis, antetokounm...
# 3  [jelang, fiba, world, cup, 2023, dikonfirmasi,...
# 4  [hasil, latihan, bebas, 4, motogp, valencia, 2...
# 5  [usai, bekuk, real, sociedad, manchester, unit...
# 6  [perbasi, kirim, 20, pemain, muda, jalani, tc,...
# 7  [hasil, nba, 20222023, hari, ini, milwaukee, b...
# 8  [ben, chilwell, dipastikan, absen, di, piala, ...
# 9  [hasil, semifinal, hylo, open, 2022, hajar, un...

# %%
data['HH'] = data['HEADLINE_NON_STP'].str.join(" ")

# %%
data['HEADLINE'] = data['HH']
data=data[['HEADLINE','CATEGORY']]

data.head(10)
# Out:
#                                             HEADLINE   CATEGORY
# 0  hasil liga inggris 20222023 semalam everton vs...  OLAH RAGA
# 1  diogo dalot dapat pujian usai tampil ciamik ke...  OLAH RAGA
# 2  nba pramusim 20222023 giannis antetokounmpo in...  OLAH RAGA
# 3  jelang fiba world cup 2023 dikonfirmasi dirut ...  OLAH RAGA
# 4  hasil latihan bebas 4 motogp valencia 2022 mig...  OLAH RAGA
# 5  usai bekuk real sociedad manchester united lan...  OLAH RAGA
# 6  perbasi kirim 20 pemain muda jalani tc ke amer...  OLAH RAGA
# 7  hasil nba 20222023 hari ini milwaukee bucks ma...  OLAH RAGA
# 8  ben chilwell dipastikan absen di piala dunia 2022  OLAH RAGA
# 9  hasil semifinal hylo open 2022 hajar unggulan ...  OLAH RAGA

# %%
data['CATEGORY'].unique()
# Out:
# array(['OLAH RAGA', 'KESEHATAN', 'EKONOMI'], dtype=object)

# %%
EKO = data[data['CATEGORY'] == 'EKONOMI']['HEADLINE'].tolist()
OLA = data[data['CATEGORY'] == 'OLAH RAGA']['HEADLINE'].tolist()
HEL = data[data['CATEGORY'] == 'KESEHATAN']['HEADLINE'].tolist()

# %%
display(len(EKO),len(OLA),len(HEL))
# Out:
# 251
# 251
# 251

# %%
EKO1 = EKO[:int(len(EKO)*0.8)]
EKO2 = EKO[int(len(EKO)*0.8):]

# %%
OLA1 = OLA[:int(len(OLA)*0.8)]
OLA2 = OLA[int(len(OLA)*0.8):]

# %%
HEL1 = HEL[:int(len(HEL)*0.8)]
HEL2 = HEL[int(len(HEL)*0.8):]

# %%
def buat1(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TRAIN/EKO/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)

def buat2(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TRAIN/OLA/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)

def buat3(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TRAIN/HEL/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)        



def buat4(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TEST/EKO/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)

def buat5(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TEST/OLA/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)

def buat6(x,y):
  with open(f'/content/drive/MyDrive/TYO_NLTK/DTS3/TEST/HEL/{x}.txt','w') as tulis:
    print(y,end='',file=tulis)

# %%
for x in range(len(EKO1)):
  buat1(x,EKO1[x])

for x in range(len(HEL1)):
  buat3(x,HEL1[x])

for x in range(len(OLA1)):
  buat2(x,OLA1[x])  



for x in range(len(EKO2)):
  buat4(x,EKO2[x])

for x in range(len(HEL2)):
  buat6(x,HEL2[x])

for x in range(len(OLA2)):
  buat5(x,OLA2[x])
